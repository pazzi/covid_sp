# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
#import functools

# %%
df=pd.read_csv("https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/dados_covid_sp.csv", sep=";", encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13284 entries, 0 to 13283
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome_munic    13284 non-null  object
#  1   codigo_ibge   13284 non-null  int64
#  2   dia           13284 non-null  int64
#  3   mes           13284 non-null  int64
#  4   datahora      13284 non-null  object
#  5   casos         13284 non-null  int64
#  6   casos_novos   12810 non-null  float64
#  7   casos_pc      13284 non-null  object
#  8   casos_mm7d    13278 non-null  object
#  9   obitos        13284 non-null  int64
#  10  obitos_novos  12810 non-null  float64
#  11  obitos_pc     13284 non-null  object
#  12  obitos_mm7d   13278 non-null  object
#  13  letalidade    13284 non-null  object
#  14  nome_ra       13284 non-null  object
#  15  cod_ra        13284 non-null  int64
#  16  nome_drs      13284 non-null  object
#  17  cod_drs       13284 non-null  int64
#  18  pop           13284 non-null  int64
#  19  pop_60        13284 non-null  int64
#  20  area          13284 non-null  int64
#  21  map_leg       13284 non-null  object
#  22  map_leg_s     13284 non-null  int64
#  23  latitude      13284 non-null  float64
#  24  longitude     13284 non-null  float64
# dtypes: float64(4), int64(11), object(10)
# memory usage: 2.5+ MB

# %%
df
# Out:
#                  nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0                     Arujá      3503901   26    3  2020-03-26      1
# 1                   Barueri      3505708   26    3  2020-03-26      3
# 2                  Caieiras      3509007   26    3  2020-03-26      2
# 3                  Campinas      3509502   26    3  2020-03-26      4
# 4               Carapicuíba      3510609   26    3  2020-03-26      2
# ...                     ...          ...  ...  ...         ...    ...
# 13279               Vinhedo      3556701   18    5  2020-05-18     57
# 13280             Viradouro      3556800   18    5  2020-05-18      1
# 13281  Vista Alegre do Alto      3556909   18    5  2020-05-18      1
# 13282            Votorantim      3557006   18    5  2020-05-18     53
# 13283           Votuporanga      3557105   18    5  2020-05-18     28
#
#        casos_novos      casos_pc    casos_mm7d  obitos  ...  cod_ra  \
# 0              NaN     1,1142806           NaN       0  ...      10
# 1              NaN     1,1346874           NaN       0  ...      10
# 2              NaN     1,9878345           NaN       0  ...      10
# 3              NaN     0,3402804           NaN       0  ...       4
# 4              NaN     0,5068449           NaN       0  ...      10
# ...            ...           ...           ...     ...  ...     ...
# 13279          0.0    73,5284633    31,0000000       2  ...       4
# 13280          0.0     5,4504824    22,0000000       1  ...       2
# 13281          0.0    12,4781632    21,4285714       0  ...       2
# 13282          1.0    44,2315396    28,8571429       3  ...      13
# 13283          0.0    30,5143854    32,0000000       1  ...      14
#
#                     nome_drs cod_drs      pop  pop_60   area map_leg  \
# 0           Grande São Paulo      10    89744   10776   9617     <10
# 1           Grande São Paulo      10   264390   29409    657     <10
# 2           Grande São Paulo      10   100612   12059   9764     <10
# 3                   Campinas       3  1175501  192796  79457     <10
# 4           Grande São Paulo      10   394598   50996   3455     <10
# ...                      ...     ...      ...     ...    ...     ...
# 13279               Campinas       3    77521   11665    816     <75
# 13280               Barretos      16    18347    2985  21773     <10
# 13281               Barretos      16     8014    1107   9543     <10
# 13282               Sorocaba       6   119824   16378  18352     <75
# 13283  São José do Rio Preto      15    91760   17203   4207     <50
#
#        map_leg_s  latitude  longitude
# 0              7  -23.3965   -46.3200
# 1              7  -23.5057   -46.8790
# 2              7  -23.3607   -46.7397
# 3              7  -22.9053   -47.0659
# 4              7  -23.5235   -46.8407
# ...          ...       ...        ...
# 13279          4  -23.0302   -46.9833
# 13280          7  -20.8734   -48.2930
# 13281          7  -21.1692   -48.6284
# 13282          4  -23.5446   -47.4388
# 13283          5  -20.4237   -49.9781
#
# [13284 rows x 25 columns]

# %%
def dados(cidade):
    filt=df['nome_munic'] == cidade
    pop=df[filt]['pop'].tolist()
    print("População:" + str(pop[0]))

    x=df[filt]['obitos'].tolist()
    total = df[filt]['obitos'].tolist()
    print("Total de obitos:" + str(total[len(total)-1]))
    print("Índice (óbitos em cada 1000):"+ str(total[len(total)-1]/pop[0]*1000))
    plt.title(cidade)
    plt.plot(x, label='Óbitos')
    plt.grid()
    #
    x=df[filt]['casos'].tolist()
    total = df[filt]['casos'].tolist()
    print("Total de casos:" + str(total[len(total)-1]))
    print("Índice (casos por mil):"+ str(total[len(total)-1]/pop[0]*1000))
    plt.title(cidade)
    plt.plot(x, label='Casos acumulados')
    plt.grid()
    #
    x=df[filt]['casos_novos'].tolist()
    plt.plot(x, label="Casos Novos por dia")
    print("Casos hoje:" + str(x[len(x)-1]))
    plt.grid()
    plt.legend()
    plt.savefig('./new_plot.png')

# %%
dados("São Paulo")
# Out:
# População:11869660
# Total de obitos:2856
# Índice (óbitos em cada 1000):0.24061346323315075
# Total de casos:36188
# Índice (casos por mil):3.0487815152245306
# Casos hoje:257.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-8f10a65e71f9> in <module>
# ----> 1 dados("São Paulo")
#
# <ipython-input-5-6c8639f82972> in dados(cidade)
#      25     plt.grid()
#      26     plt.legend()
# ---> 27     plt.savefig('./images/new_plot.png')
#      28
#
# ~/ifsp_env/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/ifsp_env/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/ifsp_env/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2096
#    2097             try:
# -> 2098                 result = print_method(
#    2099                     filename,
#    2100                     dpi=dpi,
#
# ~/ifsp_env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/ifsp_env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/ifsp_env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/new_plot.png'

# %%
dados("Piracicaba")
# Out:
# População:389873
# Total de obitos:17
# Índice (óbitos em cada 1000):0.04360394282240627
# Total de casos:226
# Índice (casos por mil):0.5796759457566951
# Casos hoje:10.0

# %%
dados("Campinas")
# Out:
# População:1175501
# Total de obitos:37
# Índice (óbitos em cada 1000):0.03147594089669001
# Total de casos:987
# Índice (casos por mil):0.8396419909468388
# Casos hoje:41.0

# %%
dados("Santos")
# Out:
# População:428703
# Total de obitos:86
# Índice (óbitos em cada 1000):0.20060508090682827
# Total de casos:1397
# Índice (casos por mil):3.258666256126036
# Casos hoje:74.0

# %%
dados("Santo André")
# Out:
# População:693867
# Total de obitos:68
# Índice (óbitos em cada 1000):0.09800149019913038
# Total de casos:1296
# Índice (casos por mil):1.8677931073246026
# Casos hoje:10.0

# %%
dados("Sumaré")
# Out:
# População:283212
# Total de obitos:3
# Índice (óbitos em cada 1000):0.010592771492733358
# Total de casos:116
# Índice (casos por mil):0.4095871643856899
# Casos hoje:9.0

# %%
dados("Hortolândia")
# Out:
# População:230268
# Total de obitos:13
# Índice (óbitos em cada 1000):0.0564559556690465
# Total de casos:106
# Índice (casos por mil):0.46033317699376375
# Casos hoje:1.0

# %%
dados("Americana")
# Out:
# População:233458
# Total de obitos:4
# Índice (óbitos em cada 1000):0.01713370285019147
# Total de casos:66
# Índice (casos por mil):0.28270609702815924
# Casos hoje:0.0

# %%
dados("Sorocaba")
# Out:
# População:658547
# Total de obitos:29
# Índice (óbitos em cada 1000):0.044036340610465165
# Total de casos:430
# Índice (casos por mil):0.6529526366379317
# Casos hoje:12.0

# %%
dados("Ribeirão Preto")
# Out:
# População:683777
# Total de obitos:13
# Índice (óbitos em cada 1000):0.01901204632504457
# Total de casos:450
# Índice (casos por mil):0.6581092958669273
# Casos hoje:14.0

# %%
dados("Monte Mor")
# Out:
# População:59614
# Total de obitos:2
# Índice (óbitos em cada 1000):0.033549166303217366
# Total de casos:18
# Índice (casos por mil):0.3019424967289563
# Casos hoje:0.0
