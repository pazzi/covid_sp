# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
#import functools

# %%
df=pd.read_csv("https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/dados_covid_sp.csv", sep=";", encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11899 entries, 0 to 11898
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome_munic    11899 non-null  object
#  1   codigo_ibge   11899 non-null  int64
#  2   dia           11899 non-null  int64
#  3   mes           11899 non-null  int64
#  4   datahora      11899 non-null  object
#  5   casos         11899 non-null  int64
#  6   casos_novos   11440 non-null  float64
#  7   casos_pc      11899 non-null  object
#  8   casos_mm7d    11893 non-null  object
#  9   obitos        11899 non-null  int64
#  10  obitos_novos  11440 non-null  float64
#  11  obitos_pc     11899 non-null  object
#  12  obitos_mm7d   11893 non-null  object
#  13  letalidade    11899 non-null  object
#  14  nome_ra       11899 non-null  object
#  15  cod_ra        11899 non-null  int64
#  16  nome_drs      11899 non-null  object
#  17  cod_drs       11899 non-null  int64
# ...

# %%
df
# Out:
#                  nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0                     Arujá      3503901   26    3  2020-03-26      1
# 1                   Barueri      3505708   26    3  2020-03-26      3
# 2                  Caieiras      3509007   26    3  2020-03-26      2
# 3                  Campinas      3509502   26    3  2020-03-26      4
# 4               Carapicuíba      3510609   26    3  2020-03-26      2
# ...                     ...          ...  ...  ...         ...    ...
# 11894               Vinhedo      3556701   15    5  2020-05-15     52
# 11895             Viradouro      3556800   15    5  2020-05-15      1
# 11896  Vista Alegre do Alto      3556909   15    5  2020-05-15      1
# 11897            Votorantim      3557006   15    5  2020-05-15     48
# 11898           Votuporanga      3557105   15    5  2020-05-15     27
#
#        casos_novos      casos_pc    casos_mm7d  obitos  ...  cod_ra  \
# ...

# %%
filt1=df['nome_munic']=="Agudos"
x=df[filt1]['casos_novos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "São Paulo"
x=df[filt]['obitos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "São Paulo"
x=df[filt]['casos_novos'].tolist()
plt.plot(x)
plt.grid()
# Out:
# nan
# 145.0
# 105.0
# 34.0
# 50.0
# 1185.0
# 397.0
# 387.0
# 294.0
# 116.0
# 142.0
# 504.0
# 689.0
# 530.0
# 505.0
# 149.0
# 221.0
# 66.0
# 287.0
# 1059.0
# 144.0
# 836.0
# 684.0
# 240.0
# 147.0
# 527.0
# 349.0
# 534.0
# 575.0
# 1298.0
# 415.0
# 476.0
# 1408.0
# 1241.0
# 1511.0
# 938.0
# 407.0
# 328.0
# 251.0
# 1067.0
# 2047.0
# 1086.0
# 1093.0
# 1421.0
# 520.0
# 464.0
# 911.0
# 1720.0
# 1471.0
# 2119.0

# %%
filt=df['nome_munic'] == "São Paulo"
x=df[filt]['casos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "Campinas"
x=df[filt]['casos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "Campinas"
x=df[filt]['obitos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "Campinas"
x=df[filt]['casos_novos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "Piracicaba"
x=df[filt]['casos_novos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "Piracicaba"
x=df[filt]['casos'].tolist()
plt.plot(x)
plt.grid()

# %%
filt=df['nome_munic'] == "Elias Fausto"
x=df[filt]['casos'].tolist()
plt.plot(x)
plt.grid()
plt.title("Elias Fausto total de casos")
# Out:
# Text(0.5, 1.0, 'Elias Fausto total de casos')

# %%
filt=df['nome_munic'] == "Elias Fausto"
x=df[filt]['casos_novos'].tolist()
plt.plot(x)
plt.grid()
plt.title("Elias Fausto - casos novos")
# Out:
# Text(0.5, 1.0, 'Elias Fausto - casos novos')
