# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
#import functools

# %%
df=pd.read_csv("https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/dados_covid_sp.csv", sep=";", encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114988 entries, 0 to 114987
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   nome_munic     114988 non-null  object
#  1   codigo_ibge    114988 non-null  int64
#  2   dia            114988 non-null  int64
#  3   mes            114988 non-null  int64
#  4   datahora       114988 non-null  object
#  5   casos          114988 non-null  int64
#  6   casos_novos    114988 non-null  int64
#  7   casos_pc       114988 non-null  object
#  8   casos_mm7d     114988 non-null  object
#  9   obitos         114988 non-null  int64
#  10  obitos_novos   114988 non-null  int64
#  11  obitos_pc      114988 non-null  object
#  12  obitos_mm7d    114988 non-null  object
#  13  letalidade     114988 non-null  object
#  14  nome_ra        114810 non-null  object
#  15  cod_ra         114988 non-null  int64
#  16  nome_drs       114810 non-null  object
#  17  cod_drs        114988 non-null  int64
#  18  pop            114988 non-null  int64
#  19  pop_60         114988 non-null  int64
#  20  area           114988 non-null  int64
#  21  map_leg        114810 non-null  object
#  22  map_leg_s      114810 non-null  float64
#  23  latitude       114988 non-null  object
#  24  longitude      114988 non-null  object
#  25  semana_epidem  114988 non-null  int64
# dtypes: float64(1), int64(13), object(12)
# memory usage: 22.8+ MB

# %%
df
# Out:
#               nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0             Adamantina      3500105   25    2  2020-02-25      0
# 1                 Adolfo      3500204   25    2  2020-02-25      0
# 2                  Aguaí      3500303   25    2  2020-02-25      0
# 3         Águas da Prata      3500402   25    2  2020-02-25      0
# 4       Águas de Lindóia      3500501   25    2  2020-02-25      0
# ...                  ...          ...  ...  ...         ...    ...
# 114983          Ignorado      9999999   16    8  2020-08-16    163
# 114984          Ignorado      9999999   17    8  2020-08-17    178
# 114985          Ignorado      9999999   18    8  2020-08-18    167
# 114986          Ignorado      9999999   19    8  2020-08-19    164
# 114987          Ignorado      9999999   20    8  2020-08-20    152
#
#         casos_novos      casos_pc    casos_mm7d  obitos  ...  \
# 0                 0  0,000000e+00     0,0000000       0  ...
# 1                 0  0,000000e+00     0,0000000       0  ...
# 2                 0  0,000000e+00     0,0000000       0  ...
# 3                 0  0,000000e+00     0,0000000       0  ...
# 4                 0  0,000000e+00     0,0000000       0  ...
# ...             ...           ...           ...     ...  ...
# 114983          -68  0,000000e+00    -7,8571429      12  ...
# 114984           15  0,000000e+00    -1,2857143       6  ...
# 114985          -11  0,000000e+00    -3,0000000       5  ...
# 114986           -3  0,000000e+00    -2,5714286       1  ...
# 114987          -12  0,000000e+00    -2,4285714       0  ...
#
#                      nome_drs cod_drs    pop pop_60   area  map_leg map_leg_s  \
# 0                     Marília       5  33894   7398  41199        0       8.0
# 1       São José do Rio Preto      15   3447    761  21106        0       8.0
# 2       São João da Boa Vista      14  35608   5245  47455        0       8.0
# 3       São João da Boa Vista      14   7797   1729  14267        0       8.0
# 4                    Campinas       3  18374   3275   6013        0       8.0
# ...                       ...     ...    ...    ...    ...      ...       ...
# 114983                    NaN       0      0      0      0      NaN       NaN
# 114984                    NaN       0      0      0      0      NaN       NaN
# 114985                    NaN       0      0      0      0      NaN       NaN
# 114986                    NaN       0      0      0      0      NaN       NaN
# 114987                    NaN       0      0      0      0      NaN       NaN
#
#         latitude  longitude  semana_epidem
# 0       -21,6820   -51,0737              9
# 1       -21,2325   -49,6451              9
# 2       -22,0572   -46,9735              9
# 3       -21,9319   -46,7176              9
# 4       -22,4733   -46,6314              9
# ...          ...        ...            ...
# 114983    0,0000     0,0000             34
# 114984    0,0000     0,0000             34
# 114985    0,0000     0,0000             34
# 114986    0,0000     0,0000             34
# 114987    0,0000     0,0000             34
#
# [114988 rows x 26 columns]

# %%
def dados(cidade):
    filt=df['nome_munic'] == cidade
    print("Dia: " + df[filt]['datahora'].tail(1).tolist()[0])
    print("Cidade:" + cidade)
    pop=df[filt]['pop'].tolist()
    print("População:" + str(pop[0]))
    x=df[filt]['obitos'].tolist()
    total = df[filt]['obitos'].tolist()
    print("Total de obitos:" + str(total[len(total)-1]))
    obitos_dia=df[filt]['obitos'].tail(2).tolist()
    print("Óbitos hoje: " +str(obitos_dia[1] - obitos_dia[0]))
    print("Índice (óbitos em cada 1000):"+ str(total[len(total)-1]/pop[0]*1000))
    plt.title(cidade)
    plt.plot(x, label='Óbitos')
    plt.grid()
    #
    x=df[filt]['casos'].tolist()
    total = df[filt]['casos'].tolist()
    print("Total de casos:" + str(total[len(total)-1]))
    print("Índice (casos por mil):"+ str(total[len(total)-1]/pop[0]*1000))
    plt.title(cidade)
    plt.plot(x, label='Casos acumulados')
    plt.grid()
    #
    x=df[filt]['casos_novos'].tolist()
    plt.plot(x, label="Casos Novos por dia")
    print("Casos hoje:" + str(x[len(x)-1]))
    plt.grid()
    plt.legend()
    #plt.savefig('./new_plot.png')

# %%
dados("São Paulo")
# Out:
# Dia: 2020-08-20
# Cidade:São Paulo
# População:11869660
# Total de obitos:10863
# Óbitos hoje: 102
# Índice (óbitos em cada 1000):0.915190494083234
# Total de casos:241764
# Índice (casos por mil):20.368232956967596
# Casos hoje:1649

# %%
dados("Piracicaba")
# Out:
# Dia: 2020-08-20
# Cidade:Piracicaba
# População:389873
# Total de obitos:256
# Óbitos hoje: 1
# Índice (óbitos em cada 1000):0.6566240801491767
# Total de casos:9148
# Índice (casos por mil):23.46405111408074
# Casos hoje:148

# %%
dados("Campinas")
# Out:
# Dia: 2020-08-20
# Cidade:Campinas
# População:1175501
# Total de obitos:923
# Óbitos hoje: 10
# Índice (óbitos em cada 1000):0.7851971202066182
# Total de casos:24706
# Índice (casos por mil):21.017421507935765
# Casos hoje:450

# %%
dados("Santos")
# Out:
# Dia: 2020-08-20
# Cidade:Santos
# População:428703
# Total de obitos:548
# Óbitos hoje: 7
# Índice (óbitos em cada 1000):1.2782742364760686
# Total de casos:18660
# Índice (casos por mil):43.52663732234204
# Casos hoje:63

# %%
dados("Santo André")
# Out:
# Dia: 2020-08-20
# Cidade:Santo André
# População:693867
# Total de obitos:471
# Óbitos hoje: 3
# Índice (óbitos em cada 1000):0.678804439467506
# Total de casos:13484
# Índice (casos por mil):19.433119027133444
# Casos hoje:205

# %%
dados("Sumaré")
# Out:
# Dia: 2020-08-20
# Cidade:Sumaré
# População:283212
# Total de obitos:131
# Óbitos hoje: 1
# Índice (óbitos em cada 1000):0.46255102184935665
# Total de casos:4868
# Índice (casos por mil):17.18853720887533
# Casos hoje:23

# %%
dados("Hortolândia")
# Out:
# Dia: 2020-08-20
# Cidade:Hortolândia
# População:230268
# Total de obitos:100
# Óbitos hoje: 1
# Índice (óbitos em cada 1000):0.43427658206958847
# Total de casos:4896
# Índice (casos por mil):21.262181458127053
# Casos hoje:52

# %%
dados("Americana")
# Out:
# Dia: 2020-08-20
# Cidade:Americana
# População:233458
# Total de obitos:102
# Óbitos hoje: 0
# Índice (óbitos em cada 1000):0.4369094226798824
# Total de casos:3351
# Índice (casos por mil):14.353759562747904
# Casos hoje:27

# %%
dados("Sorocaba")
# Out:
# Dia: 2020-08-20
# Cidade:Sorocaba
# População:658547
# Total de obitos:316
# Óbitos hoje: 1
# Índice (óbitos em cada 1000):0.4798442632036893
# Total de casos:12196
# Índice (casos por mil):18.519558968456312
# Casos hoje:103

# %%
dados("Ribeirão Preto")
# Out:
# Dia: 2020-08-20
# Cidade:Ribeirão Preto
# População:683777
# Total de obitos:517
# Óbitos hoje: 8
# Índice (óbitos em cada 1000):0.7560944576960031
# Total de casos:15530
# Índice (casos por mil):22.712083032918628
# Casos hoje:251

# %%
dados("Monte Mor")
# Out:
# Dia: 2020-08-20
# Cidade:Monte Mor
# População:59614
# Total de obitos:22
# Óbitos hoje: 1
# Índice (óbitos em cada 1000):0.369040829335391
# Total de casos:1021
# Índice (casos por mil):17.126849397792466
# Casos hoje:14

# %%
dados("Capivari")
# Out:
# Dia: 2020-08-20
# Cidade:Capivari
# População:54231
# Total de obitos:7
# Óbitos hoje: 0
# Índice (óbitos em cada 1000):0.12907746491858899
# Total de casos:690
# Índice (casos por mil):12.723350113403772
# Casos hoje:15

# %%
dados("Bragança Paulista")
# Out:
# Dia: 2020-08-20
# Cidade:Bragança Paulista
# População:163980
# Total de obitos:43
# Óbitos hoje: 1
# Índice (óbitos em cada 1000):0.2622271008659593
# Total de casos:1903
# Índice (casos por mil):11.605073789486523
# Casos hoje:56
