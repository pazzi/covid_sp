# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/dados_covid_sp.csv", sep=";", encoding="utf-8")

# %%
df.sort_values(by=['casos'], inplace=True, ascending=False)

# %%
filt1=df[(df['datahora'] == df['datahora'].max())]
#filt =(df['nome_munic'] == 'Santos')
#df[filt1 & filt]['obitos'].tolist()

# %%
#cidades=df['nome_munic'].tolist()
#cidades_un = list(dict.fromkeys(cidades))

# %%
filt1
# Out:
#                   nome_munic  codigo_ibge  dia  mes    datahora   casos  \
# 78415              São Paulo      3550308   29    6  2020-06-29  125012
# 78396                 Santos      3548500   29    6  2020-06-29    9109
# 77981               Campinas      3509502   29    6  2020-06-29    7743
# 78398  São Bernardo do Campo      3548708   29    6  2020-06-29    7491
# 78082              Guarulhos      3518800   29    6  2020-06-29    6601
# ...                      ...          ...  ...  ...         ...     ...
# 78220          Monte Castelo      3531605   29    6  2020-06-29       0
# 78227              Narandiba      3532207   29    6  2020-06-29       0
# 78347                Rifaina      3543600   29    6  2020-06-29       0
# 78050                 Fernão      3515657   29    6  2020-06-29       0
# 77927               Balbinos      3504701   29    6  2020-06-29       0
#
#        casos_novos      casos_pc    casos_mm7d  obitos  ...  \
# 78415          907  1,053206e+03  2468,7142857    7026  ...
# 78396          120  2,124781e+03   187,2857143     362  ...
# 77981          117  6,586979e+02   300,7142857     297  ...
# 78398          115  9,224392e+02   228,2857143     364  ...
# 78082          100  4,885016e+02   220,8571429     669  ...
# ...            ...           ...           ...     ...  ...
# 78220            0  0,000000e+00     0,0000000       0  ...
# 78227            0  0,000000e+00     0,0000000       0  ...
# 78347            0  0,000000e+00     0,0000000       0  ...
# 78050            0  0,000000e+00     0,0000000       0  ...
# 77927            0  0,000000e+00     0,0000000       0  ...
#
#                   nome_drs cod_drs       pop   pop_60    area map_leg  \
# 78415     Grande São Paulo      10  11869660  1853286  152111    >150
# 78396     Baixada Santista      13    428703    95433   28103    >150
# 77981             Campinas       3   1175501   192796   79457    >150
# 78398     Grande São Paulo      10    812086   122274   40953    >150
# 78082     Grande São Paulo      10   1351275   162662   31868    >150
# ...                    ...     ...       ...      ...     ...     ...
# 78220  Presidente Prudente       2      3991      936   23355       0
# 78227  Presidente Prudente       2      4841      650   35733       0
# 78347               Franca       4      3468      669   16251       0
# 78050              Marília       5      1649      316    1005       0
# 77927                Bauru      12      3704      306    9164       0
#
#        map_leg_s  latitude  longitude  semana_epidem
# 78415        1.0  -23,5329   -46,6395             27
# 78396        1.0  -23,9535   -46,3350             27
# 77981        1.0  -22,9053   -47,0659             27
# 78398        1.0  -23,6914   -46,5646             27
# 78082        1.0  -23,4538   -46,5333             27
# ...          ...       ...        ...            ...
# 78220        8.0  -21,2981   -51,5679             27
# 78227        8.0  -22,4057   -51,5274             27
# 78347        8.0  -20,0803   -47,4291             27
# 78050        8.0  -22,3607   -49,5187             27
# 77927        8.0  -21,8963   -49,3619             27
#
# [624 rows x 27 columns]

# %%
casos_100=df.sort_values(by=['casos_pc'], inplace=True, ascending=False)
